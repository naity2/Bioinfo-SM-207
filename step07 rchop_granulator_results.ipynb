# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from utils.funcs import *
from pathlib import Path
from collections import defaultdict

# stats
from scipy.stats import mannwhitneyu
# survival analysis
from lifelines.statistics import logrank_test

sns.set(font_scale = 1.25,
        style="whitegrid",
        rc={"figure.dpi":300, 'savefig.dpi':300, 'figure.figsize':(8,6)})

import warnings
warnings.filterwarnings('ignore')

# %%
data_path = Path.home() / "data/bioinfo_sm207"

# %%
response = pd.read_parquet(data_path/"step04_rchop_response.parquet")
response.head()
# Out:
#            Gene Expression Subgroup Gender   Age  PFS event    PFS time  \
# DLBCL11537                      GCB      M  58.0        0.0   47.901437
# DLBCL10477                      ABC      F  53.0        1.0    3.482546
# DLBCL10471                      ABC      M  83.0        1.0   77.864476
# DLBCL11186                      ABC      M  71.0        0.0  121.034908
# DLBCL10542                      ABC      M  30.0        1.0    6.439425
#
#            Actual Arm Code ecotyper_B.cells_group ecotyper_Plasma.cells_group  \
# DLBCL11537         Schmitz                    S02                  Unassigned
# DLBCL10477         Schmitz                    S04                  Unassigned
# DLBCL10471         Schmitz                    S05                  Unassigned
# DLBCL11186         Schmitz                    S04                         S01
# DLBCL10542         Schmitz                    S04                  Unassigned
#
#            ecotyper_T.cells.CD8_group ecotyper_T.cells.CD4_group  ...  \
# DLBCL11537                        S02                        S03  ...
# DLBCL10477                 Unassigned                 Unassigned  ...
# DLBCL10471                        S02                        S02  ...
# DLBCL11186                        S03                        S03  ...
# DLBCL10542                 Unassigned                 Unassigned  ...
#
#            granulator_Neutrophils.LD_group granulator_NK_group  \
# DLBCL11537                            high                 low
# DLBCL10477                             low                 low
# DLBCL10471                             low                 low
# DLBCL11186                             low                 low
# DLBCL10542                            high                 low
#
#            granulator_pDCs_group granulator_Plasmablasts_group  \
# DLBCL11537                  high                          high
# DLBCL10477                   low                          high
# DLBCL10471                  high                          high
# DLBCL11186                   low                           low
# DLBCL10542                   low                          high
#
#            granulator_T.CD4.Memory_group granulator_T.CD4.Naive_group  \
# DLBCL11537                          high                          low
# DLBCL10477                          high                          low
# DLBCL10471                           low                         high
# DLBCL11186                          high                          low
# DLBCL10542                           low                         high
#
#            granulator_T.CD8.Memory_group granulator_T.CD8.Naive_group  \
# DLBCL11537                          high                          low
# DLBCL10477                           low                          low
# DLBCL10471                          high                          low
# DLBCL11186                           low                          low
# DLBCL10542                           low                          low
#
#            granulator_T.gd.non.Vd2_group granulator_T.gd.Vd2_group
# DLBCL11537                           low                       low
# DLBCL10477                           low                       low
# DLBCL10471                           low                       low
# DLBCL11186                           low                      high
# DLBCL10542                          high                       low
#
# [5 rows x 54 columns]

# %%
celltypes = [c for c in response.columns if c.startswith("granulator") and "group" not in c]
len(celltypes)
# Out:
# 17

# %%
generate_stats(response, "Schmitz", ["PFS"], "granulator_T.CD8.Naive_group")
# Out:
#        Arm                     group_col param   P value        HR    lower  \
# 0  Schmitz  granulator_T.CD8.Naive_group   PFS  0.751151  1.083461  0.65981
#
#      higher
# 0  1.779128

# %%
def get_stats(arm):
    logrank_pvalues = {}
    hrs= {}
    for cell in celltypes:
        try:
            df = generate_stats(response, arm, ["PFS"], f"{cell}_group")
            logrank_pvalues[cell] = df["P value"].values[0]
            hrs[cell] = df["HR"].values[0]
        except:
            logrank_pvalues[cell] = np.nan
            hrs[cell] = np.nan

    return logrank_pvalues, hrs

# %%
pvalues_schmitz, hrs_schmitz = get_stats("Schmitz")
pvalues_reddy, hrs_reddy = get_stats("Reddy")

# %%
schmitz_res = pd.concat([pd.Series(pvalues_schmitz, name="P value (Log rank)"),
                         pd.Series(hrs_schmitz, name="Hazard Ratio")], axis=1)
schmitz_res.head()
# Out:
#                          P value (Log rank)  Hazard Ratio
# granulator_B.Memory                0.013472      0.615936
# granulator_B.Naive                 0.884136      0.972197
# granulator_Basophils.LD            0.612939      0.845645
# granulator_MAIT                    0.993311      0.998149
# granulator_mDCs                    0.719978      1.072167

# %%
reddy_res = pd.concat([pd.Series(pvalues_reddy, name="P value (Log rank)"),
                       pd.Series(hrs_reddy, name="Hazard Ratio")], axis=1)
reddy_res.head()
# Out:
#                          P value (Log rank)  Hazard Ratio
# granulator_B.Memory                0.695864      0.940050
# granulator_B.Naive                 0.584143      1.091048
# granulator_Basophils.LD            0.184003      0.620312
# granulator_MAIT                    0.302531      1.178714
# granulator_mDCs                    0.104748      1.314232

# %%
rchop_res = pd.merge(schmitz_res, reddy_res,
                    left_index=True, right_index=True,
                    suffixes=["_schmitz", "_reddy"],
                    how="outer")
rchop_res.head()
# Out:
#                          P value (Log rank)_schmitz  Hazard Ratio_schmitz  \
# granulator_B.Memory                        0.013472              0.615936
# granulator_B.Naive                         0.884136              0.972197
# granulator_Basophils.LD                    0.612939              0.845645
# granulator_MAIT                            0.993311              0.998149
# granulator_mDCs                            0.719978              1.072167
#
#                          P value (Log rank)_reddy  Hazard Ratio_reddy
# granulator_B.Memory                      0.695864            0.940050
# granulator_B.Naive                       0.584143            1.091048
# granulator_Basophils.LD                  0.184003            0.620312
# granulator_MAIT                          0.302531            1.178714
# granulator_mDCs                          0.104748            1.314232

# %%
rchop_res.index = rchop_res.index.map(lambda x: x.replace("granulator_", ""))
rchop_res.head()
# Out:
#               P value (Log rank)_schmitz  Hazard Ratio_schmitz  \
# B.Memory                        0.013472              0.615936
# B.Naive                         0.884136              0.972197
# Basophils.LD                    0.612939              0.845645
# MAIT                            0.993311              0.998149
# mDCs                            0.719978              1.072167
#
#               P value (Log rank)_reddy  Hazard Ratio_reddy
# B.Memory                      0.695864            0.940050
# B.Naive                       0.584143            1.091048
# Basophils.LD                  0.184003            0.620312
# MAIT                          0.302531            1.178714
# mDCs                          0.104748            1.314232

# %%
rchop_res.to_csv(data_path/"step07_rchop_results.csv")

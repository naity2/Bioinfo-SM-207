# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from utils.funcs import *
from pathlib import Path
from collections import defaultdict

# stats
from scipy.stats import mannwhitneyu
# survival analysis
from lifelines.statistics import logrank_test

sns.set(font_scale = 1.25,
        style="whitegrid",
        rc={"figure.dpi":300, 'savefig.dpi':300, 'figure.figsize':(8,6)})

import warnings
warnings.filterwarnings('ignore')

# %%
data_path = Path.home() / "data/bioinfo_sm207"

# %%
response = pd.read_parquet(data_path/"step04_rchop_response.parquet")
response.head()
# Out:
#    Unnamed: 0 Gene Expression Subgroup Gender   Age  PFS event    PFS time  \
# 0  DLBCL11537                      GCB      M  58.0        0.0   47.901437
# 1  DLBCL10477                      ABC      F  53.0        1.0    3.482546
# 2  DLBCL10471                      ABC      M  83.0        1.0   77.864476
# 3  DLBCL11186                      ABC      M  71.0        0.0  121.034908
# 4  DLBCL10542                      ABC      M  30.0        1.0    6.439425
#
#   Actual Arm Code ecotyper_B.cells_group ecotyper_Plasma.cells_group  \
# 0         Schmitz                    S02                  Unassigned
# 1         Schmitz                    S04                  Unassigned
# 2         Schmitz                    S05                  Unassigned
# 3         Schmitz                    S04                         S01
# 4         Schmitz                    S04                  Unassigned
#
#   ecotyper_T.cells.CD8_group  ... granulator_Neutrophils.LD_group  \
# 0                        S02  ...                            high
# 1                 Unassigned  ...                             low
# 2                        S02  ...                             low
# 3                        S03  ...                             low
# 4                 Unassigned  ...                            high
#
#   granulator_NK_group granulator_pDCs_group granulator_Plasmablasts_group  \
# 0                 low                  high                          high
# 1                 low                   low                          high
# 2                 low                  high                          high
# 3                 low                   low                           low
# 4                 low                   low                          high
#
#   granulator_T.CD4.Memory_group granulator_T.CD4.Naive_group  \
# 0                          high                          low
# 1                          high                          low
# 2                           low                         high
# 3                          high                          low
# 4                           low                         high
#
#   granulator_T.CD8.Memory_group granulator_T.CD8.Naive_group  \
# 0                          high                          low
# 1                           low                          low
# 2                          high                          low
# 3                           low                          low
# 4                           low                          low
#
#   granulator_T.gd.non.Vd2_group granulator_T.gd.Vd2_group
# 0                           low                       low
# 1                           low                       low
# 2                           low                       low
# 3                           low                      high
# 4                          high                       low
#
# [5 rows x 55 columns]

# %%
celltypes = [c for c in response.columns if c.startswith("granulator") and "group" not in c]
len(celltypes)
# Out:
# 17

# %%
generate_stats(response, "Schmitz", ["PFS"], "granulator_T.CD8.Naive_group")
# Out:
#        Arm                     group_col param   P value        HR     lower  \
# 0  Schmitz  granulator_T.CD8.Naive_group   PFS  0.751151  0.922968  0.562073
#
#      higher
# 0  1.515587

# %%
def get_stats(arm):
    logrank_pvalues = {}
    hrs= {}
    for cell in celltypes:
        try:
            df = generate_stats(response, arm, ["PFS"], f"{cell}_group")
            logrank_pvalues[cell] = df["P value"].values[0]
            hrs[cell] = df["HR"].values[0]
        except:
            logrank_pvalues[cell] = np.nan
            hrs[cell] = np.nan

    return logrank_pvalues, hrs

# %%
pvalues_schmitz, hrs_schmitz = get_stats("Schmitz")
pvalues_reddy, hrs_reddy = get_stats("Reddy")

# %%
schmitz_res = pd.concat([pd.Series(pvalues_schmitz, name="P value (Log rank)"),
                         pd.Series(hrs_schmitz, name="Hazard Ratio")], axis=1)
schmitz_res.head()
# Out:
#                          P value (Log rank)  Hazard Ratio
# granulator_B.Memory                0.013472      1.623544
# granulator_B.Naive                 0.884136      1.028598
# granulator_Basophils.LD            0.612939      1.182529
# granulator_MAIT                    0.993311      1.001855
# granulator_mDCs                    0.719978      0.932691

# %%
reddy_res = pd.concat([pd.Series(pvalues_reddy, name="P value (Log rank)"),
                       pd.Series(hrs_reddy, name="Hazard Ratio")], axis=1)
reddy_res.head()
# Out:
#                          P value (Log rank)  Hazard Ratio
# granulator_B.Memory                0.695864      1.063773
# granulator_B.Naive                 0.584143      0.916550
# granulator_Basophils.LD            0.184003      1.612091
# granulator_MAIT                    0.302531      0.848383
# granulator_mDCs                    0.104748      0.760901

# %%
rchop_res = pd.merge(schmitz_res, reddy_res,
                    left_index=True, right_index=True,
                    suffixes=["_schmitz", "_reddy"],
                    how="outer")
rchop_res.head()
# Out:
#                          P value (Log rank)_schmitz  Hazard Ratio_schmitz  \
# granulator_B.Memory                        0.013472              1.623544
# granulator_B.Naive                         0.884136              1.028598
# granulator_Basophils.LD                    0.612939              1.182529
# granulator_MAIT                            0.993311              1.001855
# granulator_mDCs                            0.719978              0.932691
#
#                          P value (Log rank)_reddy  Hazard Ratio_reddy
# granulator_B.Memory                      0.695864            1.063773
# granulator_B.Naive                       0.584143            0.916550
# granulator_Basophils.LD                  0.184003            1.612091
# granulator_MAIT                          0.302531            0.848383
# granulator_mDCs                          0.104748            0.760901

# %%
rchop_res.index = rchop_res.index.map(lambda x: x.replace("granulator_", ""))
rchop_res.head()
# Out:
#               P value (Log rank)_schmitz  Hazard Ratio_schmitz  \
# B.Memory                        0.013472              1.623544
# B.Naive                         0.884136              1.028598
# Basophils.LD                    0.612939              1.182529
# MAIT                            0.993311              1.001855
# mDCs                            0.719978              0.932691
#
#               P value (Log rank)_reddy  Hazard Ratio_reddy
# B.Memory                      0.695864            1.063773
# B.Naive                       0.584143            0.916550
# Basophils.LD                  0.184003            1.612091
# MAIT                          0.302531            0.848383
# mDCs                          0.104748            0.760901

# %%
rchop_res.to_csv(data_path/"step07_rchop_results.csv")
